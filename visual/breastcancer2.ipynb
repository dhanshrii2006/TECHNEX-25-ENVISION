# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = "breastcancer2.csv"  # Ensure the file is in the same directory as this script
data = pd.read_csv(file_path)

# %%
data = data.drop(columns=["id"], errors="ignore")

# %%
data['diagnosis'] = data['diagnosis'].map({'M': 1, 'B': 0})

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='diagnosis', data=data, palette='viridis')
plt.title('Distribution of Diagnosis (Benign vs Malignant)')
plt.xticks([0, 1], ['Benign', 'Malignant'])
plt.xlabel('Diagnosis')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\sures\AppData\Local\Temp\ipykernel_19388\2912840013.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='diagnosis', data=data, palette='viridis')

# %%
plt.figure(figsize=(12, 10))
correlation_matrix = data.corr()
sns.heatmap(correlation_matrix, cmap='coolwarm', annot=False, fmt='.2f')
plt.title('Correlation Heatmap of Features')
plt.show()
